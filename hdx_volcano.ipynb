# %% [markdown]
# # Volcano HDX data

# %%
import geopandas as gpd

# %%
data_path = "volcano.json"
# source: https://data.humdata.org/dataset/volcano-population-exposure-index-gvm
volcano_gdf = gpd.read_file(data_path)
volcano_gdf
# Out:
#       VolcanoID                     V_Name         Country  \
# 0        210010  West Eifel Volcanic Field         Germany
# 1        210020            Cha?ne des Puys          France
# 2        210030        Olot Volcanic Field           Spain
# 3        210040   Calatrava Volcanic Field           Spain
# 4        211001                 Larderello           Italy
# ...         ...                        ...             ...
# 1541     390100           Candlemas Island  United Kingdom
# 1542     390110                     Hodson  United Kingdom
# 1543     390120              Leskov Island  United Kingdom
# 1544     390130                 Zavodovski  United Kingdom
# 1545     390140            Protector Shoal  United Kingdom
#
#                         Region                              Subregion  \
# 0     Mediterranean and W Asia                         Western Europe
# 1     Mediterranean and W Asia                         Western Europe
# ...

# %%
volcano_gdf.plot(column="PEI")
# Out:
# <Axes: >

# %%
volcano_gdf.explore(column="PEI")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
